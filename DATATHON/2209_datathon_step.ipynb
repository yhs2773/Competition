# %% [markdown]
#     고객 맞춤 상품추천 서비스 도입
#
#     1. 개요 : 고객맞춤형 상품추천 서비스를 도입하여 고객 확대와 시장점유율 1위 달성
#
#     2. 진행 절차
#         1) 전처리 실행
#             i) 결측치 제거
#            ii) 중복 확인 및 조정
#           iii) 이상치 확인 및 조정
#            iv) 요일컬럼에 대한 정확한 인식 : 현재 요일구분이 척도구분으로 기재되어 있어 요일구분이 불확실 함
#                - 0,1,2,3,4,5,6에 대한 요일 matching
#                  . 1차 번호별 order 건수 , 2차 시간대별 order 건수 check 하여 구분 여부 확인 (소분류, product 포함?)
#
#          2) 설명분석(시각화 포함) : 요인별 판매 상품 분석을 통한  (order건수 check를 통한
#             i) 부서별 product별 판매상품 분석   : (ex) 냉동,알콜등 분류 order분석 )
#            ii) 소분류별 product별 판매상품 분석 : (ex) 치즈류,유기농 분류 order분석 )
#
#          3) 진단분석 : 시간대별,월별,분기별 판매분석을 통한 상품판매 진단
#             i) 분기별 상품판매   : 계절성
#            ii) 월별 상품판매     : ???
#           iii) 시간대별 상품판매 : ???
#
#          4) 예측분석 : 확인 중
#
#          5) 검증 및 확인 : scikit
#
#
#
#
#                  .

# %% [markdown]
# 1) 진행
#   - table_megre
#     i) temp1(49588건)
#        - product 테이블 + aisles name + department name
#    ii) temp2( 32434489건)
#        - order_products__prior + orders + temp1
#
#   - 현황분석
#     i) 요일 시간대별 order건수
#    ii) user별 시간대별 order건수
#        Vip vs normal : count
#        Vip 분석 : 품목 top 10 ( 소분류, department별 )
#                   일별, 시간대별
