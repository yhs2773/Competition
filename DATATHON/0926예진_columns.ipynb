# %% [markdown]
# # Orders

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
order_df = pd.read_csv('/content/drive/MyDrive/3shot/instacart-market-basket-analysis/orders.csv/orders.csv')

# %%
order_df.head(30)
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1    prior             1          2                  8
# 1    2398795        1    prior             2          3                  7
# 2     473747        1    prior             3          3                 12
# 3    2254736        1    prior             4          4                  7
# 4     431534        1    prior             5          4                 15
# 5    3367565        1    prior             6          2                  7
# 6     550135        1    prior             7          1                  9
# 7    3108588        1    prior             8          1                 14
# 8    2295261        1    prior             9          1                 16
# 9    2550362        1    prior            10          4                  8
# 10   1187899        1    train            11          4                  8
# 11   2168274        2    prior             1          2                 11
# 12   1501582        2    prior             2          5                 10
# 13   1901567        2    prior             3          1                 10
# 14    738281        2    prior             4          2                 10
# 15   1673511        2    prior             5          3                 11
# 16   1199898        2    prior             6          2                  9
# 17   3194192        2    prior             7          2                 12
# 18    788338        2    prior             8          1                 15
# 19   1718559        2    prior             9          2                  9
# 20   1447487        2    prior            10          1                 11
# 21   1402090        2    prior            11          1                 10
# 22   3186735        2    prior            12          1                  9
# 23   3268552        2    prior            13          4                 11
# 24    839880        2    prior            14          3                 10
# 25   1492625        2    train            15          1                 11
# 26   1374495        3    prior             1          1                 14
# 27    444309        3    prior             2          3                 19
# 28   3002854        3    prior             3          3                 16
# 29   2037211        3    prior             4          2                 18
#
#     days_since_prior_order
# 0                      NaN
# 1                     15.0
# 2                     21.0
# 3                     29.0
# 4                     28.0
# 5                     19.0
# 6                     20.0
# 7                     14.0
# 8                      0.0
# 9                     30.0
# 10                    14.0
# 11                     NaN
# 12                    10.0
# 13                     3.0
# 14                     8.0
# 15                     8.0
# 16                    13.0
# 17                    14.0
# 18                    27.0
# 19                     8.0
# 20                     6.0
# 21                    30.0
# 22                    28.0
# 23                    30.0
# 24                    13.0
# 25                    30.0
# 26                     NaN
# 27                     9.0
# 28                    21.0
# 29                    20.0

# %%
order_df.tail(15)
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 3421068    803273   206208     test            50          5
# 3421069   3154581   206209    prior             1          3
# 3421070   1889163   206209    prior             2          3
# 3421071   1542354   206209    prior             3          5
# 3421072    688306   206209    prior             4          1
# 3421073   2307371   206209    prior             5          4
# 3421074   3186442   206209    prior             6          0
# 3421075    550836   206209    prior             7          2
# 3421076   2129269   206209    prior             8          3
# 3421077   2558525   206209    prior             9          4
# 3421078   2266710   206209    prior            10          5
# 3421079   1854736   206209    prior            11          4
# 3421080    626363   206209    prior            12          1
# 3421081   2977660   206209    prior            13          1
# 3421082    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order
# 3421068                 11                     4.0
# 3421069                 11                     NaN
# 3421070                 17                     7.0
# 3421071                 11                    30.0
# 3421072                 10                    30.0
# 3421073                 15                     3.0
# 3421074                 16                     3.0
# 3421075                 13                     9.0
# 3421076                 17                    22.0
# 3421077                 15                    22.0
# 3421078                 18                    29.0
# 3421079                 10                    30.0
# 3421080                 12                    18.0
# 3421081                 12                     7.0
# 3421082                 14                    30.0

# %%
order_prior_df = order_df[order_df['eval_set']=='prior']
order_prior_df
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 0         2539329        1    prior             1          2
# 1         2398795        1    prior             2          3
# 2          473747        1    prior             3          3
# 3         2254736        1    prior             4          4
# 4          431534        1    prior             5          4
# ...           ...      ...      ...           ...        ...
# 3421077   2558525   206209    prior             9          4
# 3421078   2266710   206209    prior            10          5
# 3421079   1854736   206209    prior            11          4
# 3421080    626363   206209    prior            12          1
# 3421081   2977660   206209    prior            13          1
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# 2                       12                    21.0
# 3                        7                    29.0
# 4                       15                    28.0
# ...                    ...                     ...
# 3421077                 15                    22.0
# 3421078                 18                    29.0
# 3421079                 10                    30.0
# 3421080                 12                    18.0
# 3421081                 12                     7.0
#
# [3214874 rows x 7 columns]

# %%
order_prior_df.shape
# 약 321만 개의 row, column은 7개이다
# Out:
# (3214874, 7)

# %%
order_prior_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3214874 entries, 0 to 3421081
# Data columns (total 7 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   eval_set                object
#  3   order_number            int64
#  4   order_dow               int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 196.2+ MB

# %% [markdown]
# @ eval_set만 object 타입, 나중에 숫자로 변환하는 게 좋지 않을까? (ex. 0, 1, 2)

# %% [markdown]
# - order_id: order identifier
# - user_id: customer identifier
# - eval_set: which evaluation set this order belongs in - (see SET described below)
# - order_number: the order sequence number for this user (1 = first, n = nth)
# - order_dow: the day of the week the order was placed on
# - order_hour_of_day: the hour of the day the order was placed on
# - days_since_prior: days since the last order, capped at 30 (with NAs for order_number = 1)

# %% [markdown]
# - order_id : 주문 번호
# - user_id : 고객 식별번호
# - eval_set :  주문이 어떤 set에 속하는지(prior, train, test)
# - order_number : 주문번호, 한 유저가 연속으로 몇개를 주문했는지 보여준다
# - order_dow : 주문이 발생된 요일
# - order_hour_of_day : 주문이 발생된 시간
# - days_since_prior : 마지막 주문으로부터 얼마나 지났는지(최대 한도는 30일)

# %% [markdown]
# @ order_dow : 요일이 숫자로 되어 있는데, 어떤 요일이 어떤 숫자인지 파악이 필요하다

# %% [markdown]
# @ user_id가 달라도 각각의 제품에 따라 기록이 따로 되고 있으므로,
# - 각 고객의 구매 성향
# - 충성 고객의 수 파악(구매 갯수에 따라 - order_number)
# - 요일 별/ 시간 별 주문 통계
# - 어떤 고객이 / 어떤 제품을 얼마나 자주 구매하는가? (days_since_prior)
# 등을 살펴볼 수 있을 것으로 기대된다

# %%
user_count = order_prior_df['user_id'].value_counts()
user_count
# 고객 한 사람당 최대 99건, 최소 3건의 주문을 했음을 확인
# 총 고객 숫자는 206209명
# Out:
# 152340    99
# 185641    99
# 185524    99
# 81678     99
# 70922     99
#           ..
# 13046      3
# 70208      3
# 111440     3
# 31762      3
# 47980      3
# Name: user_id, Length: 206209, dtype: int64

# %%
user_count_df = pd.DataFrame([user_count])
user_count_df = user_count_df.T    # user_count_df.transpose()를 써도 같다
user_count_df
# Out:
#         user_id
# 152340       99
# 185641       99
# 185524       99
# 81678        99
# 70922        99
# ...         ...
# 13046         3
# 70208         3
# 111440        3
# 31762         3
# 47980         3
#
# [206209 rows x 1 columns]

# %%
# 구매 건수 별 구매 고객 수 확인
user_count_df.value_counts()
# 왜 98건까지만 나올까??
# Out:
# user_id
# 3          23986
# 4          19590
# 5          16165
# 6          13850
# 7          11700
#            ...
# 93            57
# 90            56
# 96            54
# 97            50
# 98            47
# Length: 97, dtype: int64

# %%
user_count_df[user_count_df['user_id']==99].value_counts()
# Out:
# user_id
# 99         1374
# dtype: int64

# %%
user_count.describe()
# Out:
# count    206209.000000
# mean         15.590367
# std          16.654774
# min           3.000000
# 25%           5.000000
# 50%           9.000000
# 75%          19.000000
# max          99.000000
# Name: user_id, dtype: float64

# %%
# 어느 시간대에 구매가 많이 이루어졌는지 확인
sns.countplot(data=order_prior_df, x='order_hour_of_day')
# 오전 7시부터 급격히 상승하여 오전 10시에 peak, 낮 12시에 약간 감소하다가 다시 상승하고, 16시 경부터 급격히 하락하기 시작
# 9 ~ 16시 사이에 가장 많은 구매가 이루어진다는 것을 알 수 있다
# 온라인 쇼핑의 특징일 수 있음

# %%
# 어느 요일에 구매가 많이 이루어졌는지를 확인
sns.countplot(data=order_prior_df, x='order_dow')
# 0과 1, 즉 일 & 월에 구매가 가장 많다. (+ 희성님 참고자료 첨부: 온라인 쇼핑 특징)

# %%
# 시간&요일별 pivot table 만들기
hod_dow_pt = pd.pivot_table(order_prior_df, values='order_number', aggfunc='count', index=['order_dow'], columns=['order_hour_of_day'])
hod_dow_pt
# Out:
# order_hour_of_day    0     1     2    3    4     5     6      7      8   \
# order_dow
# 0                  3692  2235  1299  888  750  1076  3138  11530  26223
# 1                  3475  1735  1063  711  761  1523  5101  15792  32563
# 2                  2906  1485   892  679  700  1330  4524  12550  23488
# 3                  2767  1407   889  605  666  1265  4314  11739  21305
# 4                  2476  1414   837  640  694  1251  4135  11823  20597
# 5                  2989  1539   953  796  857  1466  4573  12590  22623
# 6                  3067  1781  1137  801  747  1061  3007  10632  21522
#
# order_hour_of_day     9   ...     14     15     16     17     18     19  \
# order_dow                 ...
# 0                  37990  ...  50484  50020  45930  36874  27347  20972
# 1                  49533  ...  44220  43913  42200  34610  27293  20926
# 2                  34499  ...  35102  35408  35482  30216  24886  18922
# 3                  30653  ...  32863  33909  33284  28619  23536  18105
# 4                  29645  ...  31665  32095  32175  27577  22872  18194
# 5                  32258  ...  35131  35218  33700  28086  22700  17513
# 6                  28918  ...  36091  35569  33178  28098  22364  16988
#
# order_hour_of_day     20     21     22    23
# order_dow
# 0                  16984  13425  10440  6393
# 1                  15422  11292   8458  5322
# 2                  14223  10071   7671  5079
# 3                  13064   9718   7732  4895
# 4                  13351  10169   8274  5308
# 5                  12557   8956   7006  4953
# 6                  12508   9805   7959  5663
#
# [7 rows x 24 columns]

# %%
# 시간&요일별 히트맵 그리기
# 참고: https://noodle.tistory.com/15
plt.figure(figsize=(20,10))
plt.pcolor(hod_dow_pt)
plt.xticks(np.arange(0.5,len(hod_dow_pt.columns),1),hod_dow_pt.columns)
plt.yticks(np.arange(0.5,len(hod_dow_pt.index),1),hod_dow_pt.index)
plt.title('요일별 종료 시간 히트맵')
plt.title('Purchase Time Zone by DOW')
plt.xlabel('Hour')
plt.ylabel('Day of the Week')
plt.colorbar()
plt.show()

# 일요일 낮(13-15) & 월요일 오전(9-11)에 구매량이 높은 편임을 알 수 있다
# 금-토 여가를 즐긴 후, 가정에서 휴식을 취할 때 / 월요일 아침 출근 후 구매가 많이 발생한다고 유추할 수 있다

# %% [markdown]
# ---

# %% [markdown]
# # Aisles

# %%
aisles_df = pd.read_csv('/content/drive/MyDrive/3shot/instacart-market-basket-analysis/aisles.csv/aisles.csv')

# %%
aisles_df.head()
# Out:
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation

# %%
aisles_df.tail()
# Out:
#      aisle_id                       aisle
# 129       130    hot cereal pancake mixes
# 130       131                   dry pasta
# 131       132                      beauty
# 132       133  muscles joints pain relief
# 133       134  specialty wines champagnes

# %%
aisles_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  134 non-null    int64
#  1   aisle     134 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB

# %%
aisles_df.shape
# Out:
# (134, 2)

# %% [markdown]
# ---

# %% [markdown]
# # Products

# %%
products_df = pd.read_csv('/content/drive/MyDrive/3shot/instacart-market-basket-analysis/products.csv/products.csv')

# %%
products_df.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %%
products_df.tail()
# Out:
#        product_id                                product_name  aisle_id  \
# 49683       49684   Vodka, Triple Distilled, Twist of Vanilla       124
# 49684       49685          En Croute Roast Hazelnut Cranberry        42
# 49685       49686                            Artisan Baguette       112
# 49686       49687  Smartblend Healthy Metabolism Dry Cat Food        41
# 49687       49688                      Fresh Foaming Cleanser        73
#
#        department_id
# 49683              5
# 49684              1
# 49685              3
# 49686              8
# 49687             11

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49688 entries, 0 to 49687
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49688 non-null  int64
#  1   product_name   49688 non-null  object
#  2   aisle_id       49688 non-null  int64
#  3   department_id  49688 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %%
products_df.shape
# Out:
# (49688, 4)

# %% [markdown]
# - product_id: product identifier
# - product_name: name of the product
# - aisle_id: foreign key
# - department_id: foreign key

# %% [markdown]
# - product_id : 상품 식별자
# - product_name : 상품명
# - aisle_id : 외래키
# - department_id : 외래키

# %% [markdown]
# ---

# %% [markdown]
# # Departments

# %%
dep_df = pd.read_csv('/content/drive/MyDrive/3shot/instacart-market-basket-analysis/departments.csv/departments.csv')

# %%
dep_df.head()
# Out:
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol

# %%
dep_df.tail()
# Out:
#     department_id department
# 16             17  household
# 17             18     babies
# 18             19     snacks
# 19             20       deli
# 20             21    missing

# %%
dep_df.shape
# Out:
# (21, 2)

# %%
dep_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  21 non-null     int64
#  1   department     21 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 464.0+ bytes

# %% [markdown]
# - department_id: department identifier
# - department: the name of the department

# %% [markdown]
# - department_id: 대분류 식별자
# - department: 대분류 명

# %% [markdown]
# ---

# %% [markdown]
# # Order_products_prior

# %%
opp_df = pd.read_csv('/content/drive/MyDrive/3shot/instacart-market-basket-analysis/order_products__prior.csv/order_products__prior.csv')

# %%
opp_df.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
opp_df.tail()
# Out:
#           order_id  product_id  add_to_cart_order  reordered
# 32434484   3421083       39678                  6          1
# 32434485   3421083       11352                  7          0
# 32434486   3421083        4600                  8          0
# 32434487   3421083       24852                  9          1
# 32434488   3421083        5020                 10          1

# %%
opp_df.shape
# Out:
# (32434489, 4)

# %%
# 재구매비율이 얼마나 되는지 확인
opp_df_reorder = pd.DataFrame(opp_df['reordered'])
opp_df_reorder
# Out:
#           reordered
# 0                 1
# 1                 1
# 2                 0
# 3                 1
# 4                 0
# ...             ...
# 32434484          1
# 32434485          0
# 32434486          0
# 32434487          1
# 32434488          1
#
# [32434489 rows x 1 columns]

# %%
opp_df_reorder.value_counts()
# 재구매: 19,126,536건
# 첫 구매: 13,307,953건
# Out:
# reordered
# 1            19126536
# 0            13307953
# dtype: int64

# %%
sns.countplot(data=opp_df_reorder, x='reordered')
# 재구매가 첫 구매에 비해서 높다
# 기존 구매 고객층(특히 vip)을 굳건히 할 필요성의 근거

# %%
opp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32434489 entries, 0 to 32434488
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int64
#  1   product_id         int64
#  2   add_to_cart_order  int64
#  3   reordered          int64
# dtypes: int64(4)
# memory usage: 989.8 MB

# %% [markdown]
# - order_id: foreign key
# - product_id: foreign key
# - add_to_cart_order: order in which each product was added to cart
# - reordered: 1 if this product has been ordered by this user in the past, 0 otherwise

# %% [markdown]
# - order_id: 외래 키
# - product_id: 외래 키
# - add_to_cart_order: 각 상품이 카트에 들어간 주문
# - reordered: 과거 주문 이력이 있으면 1, 아니면 0

# %% [markdown]
# ---

# %% [markdown]
# # Order_products_train

# %%
opt_df = pd.read_csv('/content/drive/MyDrive/3shot/instacart-market-basket-analysis/order_products__train.csv/order_products__train.csv')

# %%
opt_df.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         1       49302                  1          1
# 1         1       11109                  2          1
# 2         1       10246                  3          0
# 3         1       49683                  4          0
# 4         1       43633                  5          1

# %%
opt_df.tail()
# Out:
#          order_id  product_id  add_to_cart_order  reordered
# 1384612   3421063       14233                  3          1
# 1384613   3421063       35548                  4          1
# 1384614   3421070       35951                  1          1
# 1384615   3421070       16953                  2          1
# 1384616   3421070        4724                  3          1

# %%
opt_df.shape
# Out:
# (1384617, 4)

# %%
opt_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1384617 entries, 0 to 1384616
# Data columns (total 4 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   order_id           1384617 non-null  int64
#  1   product_id         1384617 non-null  int64
#  2   add_to_cart_order  1384617 non-null  int64
#  3   reordered          1384617 non-null  int64
# dtypes: int64(4)
# memory usage: 42.3 MB

# %% [markdown]
# - order_id: foreign key
# - product_id: foreign key
# - add_to_cart_order: order in which each product was added to cart
# - reordered: 1 if this product has been ordered by this user in the past, 0 otherwise

# %% [markdown]
# - order_id: 외래 키
# - product_id: 외래 키
# - add_to_cart_order: 각 상품이 카트에 들어간 주문
# - reordered: 과거 주문 이력이 있으면 1, 아니면 0

# %% [markdown]
# @ 과거 주문 이력이 없으면서 + 카트에 담아두기를 한 사람 >> 새로운 고객층으로 만들기 위한 목표설정도 가능할 것으로 보인다

# %% [markdown]
# # Merge

# %% [markdown]
# 우리 회사(Instacart)는 다양한 마켓을 연결하여 고객에게 상품을 제공하는 온라인 쇼핑몰이다. <br>
# 우리 회사는 직접 상품을 판매하는 회사가 아니므로, 거래 시 발생하는 수수료를 통해 매출을 증대해야 한다. <br>
# 따라서 한 번에 많은 양을 구입하는 고객보다는, 적게 구매하더라도 자주 구매하는 고객들이 우리의 VIP 고객들이다. <br>
# VIP 고객들의 구매패턴을 파악하기 위해 VIP 고객에 대한 분석을 먼저 시작하였다.
# <br>
# <br>
# 자주 산다: order number 숫자가 높다
# 이를 확인하기 위해서 boxplot으로 확인해보았다

# %%
# merging products and aisles df based on product id
temp1 = pd.merge(left=products_df, right=aisles_df, how='left')
# merging products and departments df based on product id
temp1 = pd.merge(left=temp1, right=dep_df, how='left')
temp1

# 시각화 하기 (소분류 별, 대분류별, 프로덕트)
# 대분류는 히스토그램
# 소분류는 히스토그램 탑 10 또는 라인그래프 ...
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49683       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49684       49685                 En Croute Roast Hazelnut Cranberry
# 49685       49686                                   Artisan Baguette
# 49686       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49687       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id                       aisle     department
# 0            61             19               cookies cakes         snacks
# 1           104             13           spices seasonings         pantry
# 2            94              7                         tea      beverages
# 3            38              1                frozen meals         frozen
# 4             5             13  marinades meat preparation         pantry
# ...         ...            ...                         ...            ...
# 49683       124              5                     spirits        alcohol
# 49684        42              1     frozen vegan vegetarian         frozen
# 49685       112              3                       bread         bakery
# 49686        41              8               cat food care           pets
# 49687        73             11                 facial care  personal care
#
# [49688 rows x 6 columns]

# %%
# merging order prior and temp1 based on prior
temp2 = pd.merge(left=opp_df, right=temp1, how='left')
# merging order prior and orders df based on prior
temp2 = pd.merge(left=temp2, right=order_df, how='left')
temp2
# Out:
#           order_id  product_id  add_to_cart_order  reordered  \
# 0                2       33120                  1          1
# 1                2       28985                  2          1
# 2                2        9327                  3          0
# 3                2       45918                  4          1
# 4                2       30035                  5          0
# ...            ...         ...                ...        ...
# 32434484   3421083       39678                  6          1
# 32434485   3421083       11352                  7          0
# 32434486   3421083        4600                  8          0
# 32434487   3421083       24852                  9          1
# 32434488   3421083        5020                 10          1
#
#                                                product_name  aisle_id  \
# 0                                        Organic Egg Whites        86
# 1                                     Michigan Organic Kale        83
# 2                                             Garlic Powder       104
# 3                                            Coconut Butter        19
# 4                                         Natural Sweetener        17
# ...                                                     ...       ...
# 32434484          Free & Clear Natural Dishwasher Detergent        74
# 32434485       Organic Mini Sandwich Crackers Peanut Butter        78
# 32434486                    All Natural French Toast Sticks        52
# 32434487                                             Banana        24
# 32434488  Organic  Sweet & Salty Peanut Pretzel Granola ...         3
#
#           department_id                aisle  department  user_id eval_set  \
# 0                    16                 eggs  dairy eggs   202279    prior
# 1                     4     fresh vegetables     produce   202279    prior
# 2                    13    spices seasonings      pantry   202279    prior
# 3                    13        oils vinegars      pantry   202279    prior
# 4                    13   baking ingredients      pantry   202279    prior
# ...                 ...                  ...         ...      ...      ...
# 32434484             17      dish detergents   household    25247    prior
# 32434485             19             crackers      snacks    25247    prior
# 32434486              1     frozen breakfast      frozen    25247    prior
# 32434487              4         fresh fruits     produce    25247    prior
# 32434488             19  energy granola bars      snacks    25247    prior
#
#           order_number  order_dow  order_hour_of_day  days_since_prior_order
# 0                    3          5                  9                     8.0
# 1                    3          5                  9                     8.0
# 2                    3          5                  9                     8.0
# 3                    3          5                  9                     8.0
# 4                    3          5                  9                     8.0
# ...                ...        ...                ...                     ...
# 32434484            24          2                  6                    21.0
# 32434485            24          2                  6                    21.0
# 32434486            24          2                  6                    21.0
# 32434487            24          2                  6                    21.0
# 32434488            24          2                  6                    21.0
#
# [32434489 rows x 15 columns]

# %%
# user_id, order_id, department_n, aisles_n, product_n, prod_name, add to cart, reordered< - temp 3
# 지울 열: eval_set, aisle_id, department_id
temp3 = temp2[['user_id', 'order_id', 'department', 'aisle', 'product_name', 'order_number', 'add_to_cart_order', 'reordered']]
temp3
# Out:
#           user_id  order_id  department                aisle  \
# 0          202279         2  dairy eggs                 eggs
# 1          202279         2     produce     fresh vegetables
# 2          202279         2      pantry    spices seasonings
# 3          202279         2      pantry        oils vinegars
# 4          202279         2      pantry   baking ingredients
# ...           ...       ...         ...                  ...
# 32434484    25247   3421083   household      dish detergents
# 32434485    25247   3421083      snacks             crackers
# 32434486    25247   3421083      frozen     frozen breakfast
# 32434487    25247   3421083     produce         fresh fruits
# 32434488    25247   3421083      snacks  energy granola bars
#
#                                                product_name  order_number  \
# 0                                        Organic Egg Whites             3
# 1                                     Michigan Organic Kale             3
# 2                                             Garlic Powder             3
# 3                                            Coconut Butter             3
# 4                                         Natural Sweetener             3
# ...                                                     ...           ...
# 32434484          Free & Clear Natural Dishwasher Detergent            24
# 32434485       Organic Mini Sandwich Crackers Peanut Butter            24
# 32434486                    All Natural French Toast Sticks            24
# 32434487                                             Banana            24
# 32434488  Organic  Sweet & Salty Peanut Pretzel Granola ...            24
#
#           add_to_cart_order  reordered
# 0                         1          1
# 1                         2          1
# 2                         3          0
# 3                         4          1
# 4                         5          0
# ...                     ...        ...
# 32434484                  6          1
# 32434485                  7          0
# 32434486                  8          0
# 32434487                  9          1
# 32434488                 10          1
#
# [32434489 rows x 8 columns]

# %%
# VIP를 가려내기 위해 user_id별로 오더 건수를 세봤다
temp3.groupby('user_id').count()['order_id']
# Out:
# user_id
# 1          59
# 2         195
# 3          88
# 4          18
# 5          37
#          ...
# 206205     32
# 206206    285
# 206207    223
# 206208    677
# 206209    129
# Name: order_id, Length: 206209, dtype: int64

# %%
# 예를 들어서 유저 4에 오더건수가 18건이라서 한번에 보고 싶어서 확인했다.
temp3[temp3['user_id']==4]
# Out:
#           user_id  order_id    department                          aisle  \
# 897542          4     94891       alcohol     specialty wines champagnes
# 897543          4     94891     beverages                   refrigerated
# 6547608         4    691089  canned goods            soup broth bouillon
# 6547609         4    691089     beverages                    soft drinks
# 6547610         4    691089        bakery           tortillas flat bread
# 6547611         4    691089       produce                   fresh fruits
# 6547612         4    691089        frozen                   frozen meals
# 6547613         4    691089        frozen                   frozen meals
# 6547614         4    691089       produce                   fresh fruits
# 19249953        4   2030307       alcohol                      red wines
# 19249954        4   2030307     household     plates bowls cups flatware
# 24252819        4   2557754        snacks                 chips pretzels
# 24252820        4   2557754          deli           fresh dips tapenades
# 24252821        4   2557754          deli           fresh dips tapenades
# 31695751        4   3343014        bakery                          bread
# 31695752        4   3343014     beverages  water seltzer sparkling water
# 31695753        4   3343014        frozen                   frozen meals
# 31695754        4   3343014     household                dish detergents
#
#                                                product_name  order_number  \
# 897542                                       Extra-Dry Cava             4
# 897543                                Original Orange Juice             4
# 6547608                   Vegetable Classics Vegetable Soup             3
# 6547609   Diet Caffeine Free Naturally Flavored Lemon Li...             3
# 6547610                      Low Carb Whole Wheat Tortillas             3
# 6547611                                 Organic Gala Apples             3
# 6547612   Light & Lean Spaghetti Italiano with Meatless ...             3
# 6547613                      Enchilada Black Bean Vegetable             3
# 6547614                Organic Large Extra Fancy Fuji Apple             3
# 19249953                       Private Selection Pinot Noir             2
# 19249954                                         Clear Cups             2
# 24252819                         Yellow Corn Tortilla Chips             5
# 24252820                                     Real Guacamole             5
# 24252821                            Roasted Pine Nut Hummus             5
# 31695751                         Sprouted Multi-Grain Bread             1
# 31695752        Natural Lime Flavor Sparkling Mineral Water             1
# 31695753                     Enchilada Black Bean Vegetable             1
# 31695754  Complete™ ActionPacs™ Fresh Scent Dishwasher D...             1
#
#           add_to_cart_order  reordered
# 897542                    1          0
# 897543                    2          0
# 6547608                   1          0
# 6547609                   2          0
# 6547610                   3          0
# 6547611                   4          0
# 6547612                   5          0
# 6547613                   6          1
# 6547614                   7          0
# 19249953                  1          0
# 19249954                  2          0
# 24252819                  1          0
# 24252820                  2          0
# 24252821                  3          0
# 31695751                  1          0
# 31695752                  2          0
# 31695753                  3          0
# 31695754                  4          0

# %%
# 고객별로 주문한 횟수 order_number로 확인가능
# 조금 더 간단하게 VIP확인을 위해 prior df말고 더 작은 orders df을 사용했다.
# 필터링 조건이 prior data 그리고 user_id별 카운트
order_number_count = order_df[order_df['eval_set']=='prior'].groupby(['user_id']).count()
order_number_count
# Out:
#          order_id  eval_set  order_number  order_dow  order_hour_of_day  \
# user_id
# 1              10        10            10         10                 10
# 2              14        14            14         14                 14
# 3              12        12            12         12                 12
# 4               5         5             5          5                  5
# 5               4         4             4          4                  4
# ...           ...       ...           ...        ...                ...
# 206205          3         3             3          3                  3
# 206206         67        67            67         67                 67
# 206207         16        16            16         16                 16
# 206208         49        49            49         49                 49
# 206209         13        13            13         13                 13
#
#          days_since_prior_order
# user_id
# 1                             9
# 2                            13
# 3                            11
# 4                             4
# 5                             3
# ...                         ...
# 206205                        2
# 206206                       66
# 206207                       15
# 206208                       48
# 206209                       12
#
# [206209 rows x 6 columns]

# %%
# 통계치 숫자로 확인
order_number_count.describe()
# 시각화: 통계치 그래프 그리기
# 정규분포화된 곡선 그래프 kde
# Out:
#             order_id       eval_set   order_number      order_dow  \
# count  206209.000000  206209.000000  206209.000000  206209.000000
# mean       15.590367      15.590367      15.590367      15.590367
# std        16.654774      16.654774      16.654774      16.654774
# min         3.000000       3.000000       3.000000       3.000000
# 25%         5.000000       5.000000       5.000000       5.000000
# 50%         9.000000       9.000000       9.000000       9.000000
# 75%        19.000000      19.000000      19.000000      19.000000
# max        99.000000      99.000000      99.000000      99.000000
#
#        order_hour_of_day  days_since_prior_order
# count      206209.000000           206209.000000
# mean           15.590367               14.590367
# std            16.654774               16.654774
# min             3.000000                2.000000
# 25%             5.000000                4.000000
# 50%             9.000000                8.000000
# 75%            19.000000               18.000000
# max            99.000000               98.000000

# %%
# 박스플롯으로 백분위수를 시각화함과 동시에 이상치를 확인하려고 그렸다.
# 여기서 order_number 40 이상이 이상치로 발견
# 그래서 이상치가 몇명인지 궁금해서 확인해보기로 했다.
plt.figure(figsize=(30,10))
sns.boxplot(data=order_number_count, x='order_number')

# %%
order_number_count['order_number'].describe()
# Out:
# count    206209.000000
# mean         15.590367
# std          16.654774
# min           3.000000
# 25%           5.000000
# 50%           9.000000
# 75%          19.000000
# max          99.000000
# Name: order_number, dtype: float64

# %%
# 가설: order_number가 40 인 이상을 확인
order_number_vip = order_number_count[order_number_count['order_number'] >= 40]
order_number_vip
# Out:
#          order_id  eval_set  order_number  order_dow  order_hour_of_day  \
# user_id
# 17             40        40            40         40                 40
# 27             81        81            81         81                 81
# 50             67        67            67         67                 67
# 54             77        77            77         77                 77
# 90             71        71            71         71                 71
# ...           ...       ...           ...        ...                ...
# 206158         50        50            50         50                 50
# 206174         52        52            52         52                 52
# 206193         41        41            41         41                 41
# 206206         67        67            67         67                 67
# 206208         49        49            49         49                 49
#
#          days_since_prior_order
# user_id
# 17                           39
# 27                           80
# 50                           66
# 54                           76
# 90                           70
# ...                         ...
# 206158                       49
# 206174                       51
# 206193                       40
# 206206                       66
# 206208                       48
#
# [17902 rows x 6 columns]

# %%
order_number_normal = order_number_count[order_number_count['order_number'] < 40]
order_number_normal
# Out:
#          order_id  eval_set  order_number  order_dow  order_hour_of_day  \
# user_id
# 1              10        10            10         10                 10
# 2              14        14            14         14                 14
# 3              12        12            12         12                 12
# 4               5         5             5          5                  5
# 5               4         4             4          4                  4
# ...           ...       ...           ...        ...                ...
# 206203          5         5             5          5                  5
# 206204          4         4             4          4                  4
# 206205          3         3             3          3                  3
# 206207         16        16            16         16                 16
# 206209         13        13            13         13                 13
#
#          days_since_prior_order
# user_id
# 1                             9
# 2                            13
# 3                            11
# 4                             4
# 5                             3
# ...                         ...
# 206203                        4
# 206204                        3
# 206205                        2
# 206207                       15
# 206209                       12
#
# [188307 rows x 6 columns]

# %%
# order df 전체 고객수 대비 대략 8.68% 가 40번 이상 구매한 고객이었다
17902/206209
# Out:
# 0.08681483349417339

# %%
# 이 가설을 prior에 적용시켜보았다 
# 40번 이상 구매한 고객들의 구매한 제품 건수
temp4 = temp3[temp3['order_number'] >=40]
temp4
# Out:
#           user_id  order_id  department                       aisle  \
# 30         156122         5     produce                fresh fruits
# 31         156122         5      pantry     salad dressing toppings
# 32         156122         5        deli       prepared soups salads
# 33         156122         5     produce  packaged vegetables fruits
# 34         156122         5  dairy eggs                        milk
# ...           ...       ...         ...                         ...
# 32434398   119835   3421069     produce                fresh fruits
# 32434399   119835   3421069     produce            fresh vegetables
# 32434400   119835   3421069     produce            fresh vegetables
# 32434401   119835   3421069     produce            fresh vegetables
# 32434402   119835   3421069     produce                fresh fruits
#
#                                   product_name  order_number  \
# 30                      Bag of Organic Bananas            42
# 31                        Just Crisp, Parmesan            42
# 32                           Fresh Fruit Salad            42
# 33                         Organic Raspberries            42
# 34                         2% Reduced Fat Milk            42
# ...                                        ...           ...
# 32434398                  Organic Strawberries            75
# 32434399                      Organic Cucumber            75
# 32434400                    Organic Red Potato            75
# 32434401         Organic Large Green Asparagus            75
# 32434402  Organic Large Extra Fancy Fuji Apple            75
#
#           add_to_cart_order  reordered
# 30                        1          1
# 31                        2          1
# 32                        3          1
# 33                        4          1
# 34                        5          1
# ...                     ...        ...
# 32434398                  8          1
# 32434399                  9          1
# 32434400                 10          1
# 32434401                 11          1
# 32434402                 12          1
#
# [3595154 rows x 8 columns]

# %%
temp3[temp3['user_id']==156122]
# Out:
#           user_id  order_id  department                       aisle  \
# 30         156122         5     produce                fresh fruits
# 31         156122         5      pantry     salad dressing toppings
# 32         156122         5        deli       prepared soups salads
# 33         156122         5     produce  packaged vegetables fruits
# 34         156122         5  dairy eggs                        milk
# ...           ...       ...         ...                         ...
# 32102348   156122   3386168      snacks               cookies cakes
# 32102349   156122   3386168      snacks      nuts seeds dried fruit
# 32102350   156122   3386168   household                 paper goods
# 32102351   156122   3386168   household             dish detergents
# 32102352   156122   3386168      frozen               ice cream ice
#
#                             product_name  order_number  add_to_cart_order  \
# 30                Bag of Organic Bananas            42                  1
# 31                  Just Crisp, Parmesan            42                  2
# 32                     Fresh Fruit Salad            42                  3
# 33                   Organic Raspberries            42                  4
# 34                   2% Reduced Fat Milk            42                  5
# ...                                  ...           ...                ...
# 32102348           Biscuits Orange Pim's            19                  3
# 32102349      No Salt Roasted Pistachios            19                  4
# 32102350          Sensitive Toilet Paper            19                  5
# 32102351  Classic Scent Liquid Dish Soap            19                  6
# 32102352          Mini Classic Ice Cream            19                  7
#
#           reordered
# 30                1
# 31                1
# 32                1
# 33                1
# 34                1
# ...             ...
# 32102348          1
# 32102349          1
# 32102350          1
# 32102351          1
# 32102352          1
#
# [967 rows x 8 columns]

# %%
#temp4[temp4['user_id']==156122]

# %%
# VIP고객이 제품을 많이 구매했다
# 대략 32.8%의 제품을 오더했다
10661601/32454490
# Out:
# 0.3285092756040844

# %%
# VIP = 40번 이상 구매한 고객수, 수수료로 설명가능 = 대략 27.21%
# 일반고객 = 40번 미만 구매한 고객수 대략 100-27.21 = 

# 해야 할 일: 정리 코랩 하고 내용

# %%
order_number_vip.describe()
# Out:
#            order_id      eval_set  order_number     order_dow  \
# count  17902.000000  17902.000000  17902.000000  17902.000000
# mean      59.209641     59.209641     59.209641     59.209641
# std       17.690520     17.690520     17.690520     17.690520
# min       40.000000     40.000000     40.000000     40.000000
# 25%       45.000000     45.000000     45.000000     45.000000
# 50%       53.000000     53.000000     53.000000     53.000000
# 75%       68.000000     68.000000     68.000000     68.000000
# max       99.000000     99.000000     99.000000     99.000000
#
#        order_hour_of_day  days_since_prior_order
# count       17902.000000            17902.000000
# mean           59.209641               58.209641
# std            17.690520               17.690520
# min            40.000000               39.000000
# 25%            45.000000               44.000000
# 50%            53.000000               52.000000
# 75%            68.000000               67.000000
# max            99.000000               98.000000

# %%
order_number_normal = order_number_count[order_number_count['order_number'] < 40]
order_number_normal
# Out:
#          order_id  eval_set  order_number  order_dow  order_hour_of_day  \
# user_id
# 1              10        10            10         10                 10
# 2              14        14            14         14                 14
# 3              12        12            12         12                 12
# 4               5         5             5          5                  5
# 5               4         4             4          4                  4
# ...           ...       ...           ...        ...                ...
# 206203          5         5             5          5                  5
# 206204          4         4             4          4                  4
# 206205          3         3             3          3                  3
# 206207         16        16            16         16                 16
# 206209         13        13            13         13                 13
#
#          days_since_prior_order
# user_id
# 1                             9
# 2                            13
# 3                            11
# 4                             4
# 5                             3
# ...                         ...
# 206203                        4
# 206204                        3
# 206205                        2
# 206207                       15
# 206209                       12
#
# [188307 rows x 6 columns]

# %%
len(order_number_normal)/len(order_number_count)
# Out:
# 0.9131851665058266

# %%
order_number_normal.describe()
# Out:
#             order_id       eval_set   order_number      order_dow  \
# count  188307.000000  188307.000000  188307.000000  188307.000000
# mean       11.443563      11.443563      11.443563      11.443563
# std         8.713417       8.713417       8.713417       8.713417
# min         3.000000       3.000000       3.000000       3.000000
# 25%         5.000000       5.000000       5.000000       5.000000
# 50%         8.000000       8.000000       8.000000       8.000000
# 75%        16.000000      16.000000      16.000000      16.000000
# max        39.000000      39.000000      39.000000      39.000000
#
#        order_hour_of_day  days_since_prior_order
# count      188307.000000           188307.000000
# mean           11.443563               10.443563
# std             8.713417                8.713417
# min             3.000000                2.000000
# 25%             5.000000                4.000000
# 50%             8.000000                7.000000
# 75%            16.000000               15.000000
# max            39.000000               38.000000

# %%
# VIP vs normal pie graph or histrogram 고객 숫자 그래프

# %%
# 통계 그래프 VIP vs normal

# %%
# 가설확인: 전체 수수료 대비 VIP가 차지하는 비율: 대략 8%의 고객이 32%의 매출(order_number * fee)을 올렸다
# 시각화 pie graph 필요
fee = 2.99
vip_fee = fee * order_number_vip['order_number'].mean() * len(order_number_vip)
normal_fee = fee * order_number_normal['order_number'].mean() * (len(order_number_count)-len(order_number_vip))
total_fee = vip_fee + normal_fee
print(vip_fee)
print(normal_fee)
print(vip_fee / total_fee)

fee_df = pd.DataFrame([vip_fee, normal_fee], index=['VIP', 'Normal'])
fee_df
plt.figure(figsize=(8, 8))
plt.pie(fee_df, labels=fee_df.index, autopct='%.2f%%')
plt.title('Fee comparison between VIP and Normal')
plt.show()
# Out:
# 3169313.2900000005
# 6443159.970000002
# 0.3297084115893811
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.

# %%
# 해야 할 일: VIP 품목 구매 패턴 분석 (소분류, 대분류)
# 해야 할 일: 예측 분석 (가설)
# 해야 할 일: 모델 정하기 ()
# 해야 할 일:

# %%
order_number_vip.info()
order_number_vip
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17902 entries, 17 to 206208
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   order_id                17902 non-null  int64
#  1   eval_set                17902 non-null  int64
#  2   order_number            17902 non-null  int64
#  3   order_dow               17902 non-null  int64
#  4   order_hour_of_day       17902 non-null  int64
#  5   days_since_prior_order  17902 non-null  int64
# dtypes: int64(6)
# memory usage: 979.0 KB
#          order_id  eval_set  order_number  order_dow  order_hour_of_day  \
# user_id
# 17             40        40            40         40                 40
# 27             81        81            81         81                 81
# 50             67        67            67         67                 67
# 54             77        77            77         77                 77
# 90             71        71            71         71                 71
# ...           ...       ...           ...        ...                ...
# 206158         50        50            50         50                 50
# 206174         52        52            52         52                 52
# 206193         41        41            41         41                 41
# 206206         67        67            67         67                 67
# 206208         49        49            49         49                 49
#
#          days_since_prior_order
# user_id
# 17                           39
# 27                           80
# 50                           66
# 54                           76
# 90                           70
# ...                         ...
# 206158                       49
# 206174                       51
# 206193                       40
# 206206                       66
# 206208                       48
#
# [17902 rows x 6 columns]

# %%
order_number_vip2 = order_number_vip.reset_index()
order_number_vip2 = order_number_vip2['user_id']
order_number_vip2
# Out:
# 0            17
# 1            27
# 2            50
# 3            54
# 4            90
#           ...
# 17897    206158
# 17898    206174
# 17899    206193
# 17900    206206
# 17901    206208
# Name: user_id, Length: 17902, dtype: int64

# %%
vip_df = pd.merge(left=order_number_vip2, right=temp2, how='left')
vip_df
# Out:
#           user_id  order_id  product_id  add_to_cart_order  reordered  \
# 0              17    343199        7350                  1          1
# 1              17    343199       18534                  2          1
# 2              17    343199       17762                  3          1
# 3              17    343199       48544                  4          1
# 4              17    343199        4591                  5          0
# ...           ...       ...         ...                ...        ...
# 10661596   206208   3412250       14467                  8          1
# 10661597   206208   3412250       23644                  9          1
# 10661598   206208   3412250       21461                 10          0
# 10661599   206208   3412250       31506                 11          1
# 10661600   206208   3412250       31404                 12          1
#
#                                                product_name  aisle_id  \
# 0               Natural Lime Flavor Sparkling Mineral Water       115
# 1                                  Grade A Extra Large Eggs        86
# 2                                    Light Oaked Chardonnay        62
# 3         Compleats Chicken Breast Gravy Mashed Potatoes...         4
# 4                                    Quick 1 Minute Oatmeal       130
# ...                                                     ...       ...
# 10661596                                     Sweet Baguette       112
# 10661597                  Sharp Cheddar Thick Slices Cheese        21
# 10661598                             Triple Creme Goat Brie        21
# 10661599                             Extra Virgin Olive Oil        19
# 10661600                                    Vanilla Yoghurt       120
#
#           department_id                          aisle       department  \
# 0                     7  water seltzer sparkling water        beverages
# 1                    16                           eggs       dairy eggs
# 2                     5                    white wines          alcohol
# 3                     9                  instant foods  dry goods pasta
# 4                    14       hot cereal pancake mixes        breakfast
# ...                 ...                            ...              ...
# 10661596              3                          bread           bakery
# 10661597             16                packaged cheese       dairy eggs
# 10661598             16                packaged cheese       dairy eggs
# 10661599             13                  oils vinegars           pantry
# 10661600             16                         yogurt       dairy eggs
#
#          eval_set  order_number  order_dow  order_hour_of_day  \
# 0           prior            26          5                 17
# 1           prior            26          5                 17
# 2           prior            26          5                 17
# 3           prior            26          5                 17
# 4           prior            26          5                 17
# ...           ...           ...        ...                ...
# 10661596    prior            29          4                 18
# 10661597    prior            29          4                 18
# 10661598    prior            29          4                 18
# 10661599    prior            29          4                 18
# 10661600    prior            29          4                 18
#
#           days_since_prior_order
# 0                            5.0
# 1                            5.0
# 2                            5.0
# 3                            5.0
# 4                            5.0
# ...                          ...
# 10661596                     4.0
# 10661597                     4.0
# 10661598                     4.0
# 10661599                     4.0
# 10661600                     4.0
#
# [10661601 rows x 15 columns]

# %%
vip_df[vip_df['user_id'] == 27]
# Out:
#       user_id  order_id  product_id  add_to_cart_order  reordered  \
# 294        27      7099        6799                  1          0
# 295        27      7099        8580                  2          0
# 296        27      7099       31231                  3          0
# 297        27      7099        1185                  4          0
# 298        27      7099       44051                  5          0
# ...       ...       ...         ...                ...        ...
# 1057       27   3374715       42828                 10          0
# 1058       27   3374715        4781                 11          1
# 1059       27   3374715       38777                 12          0
# 1060       27   3374715       24236                 13          0
# 1061       27   3374715       42356                 14          0
#
#                                            product_name  aisle_id  \
# 294                           Revive Zero Vitamin Water        64
# 295   VitaminWater Zero™ XXX Acai Blueberry Pomegranate        64
# 296                      Vitamin Water Zero Rise Orange        64
# 297          Energy Tropical Citrus Vitamin Water Drink        64
# 298                                  Zero Vitamin Water        64
# ...                                                 ...       ...
# 1057                               Whipped Cream Cheese       108
# 1058                      Original Coconut Milk Creamer        91
# 1059                      Organic Green Seedless Grapes       123
# 1060  Organic  Dried & Unsulfured Orchard Select Apr...       117
# 1061                               Strawberry Preserves        88
#
#       department_id                       aisle  department eval_set  \
# 294               7        energy sports drinks   beverages    prior
# 295               7        energy sports drinks   beverages    prior
# 296               7        energy sports drinks   beverages    prior
# 297               7        energy sports drinks   beverages    prior
# 298               7        energy sports drinks   beverages    prior
# ...             ...                         ...         ...      ...
# 1057             16        other creams cheeses  dairy eggs    prior
# 1058             16             soy lactosefree  dairy eggs    prior
# 1059              4  packaged vegetables fruits     produce    prior
# 1060             19      nuts seeds dried fruit      snacks    prior
# 1061             13                     spreads      pantry    prior
#
#       order_number  order_dow  order_hour_of_day  days_since_prior_order
# 294             63          3                 10                     1.0
# 295             63          3                 10                     1.0
# 296             63          3                 10                     1.0
# 297             63          3                 10                     1.0
# 298             63          3                 10                     1.0
# ...            ...        ...                ...                     ...
# 1057            40          4                 10                     3.0
# 1058            40          4                 10                     3.0
# 1059            40          4                 10                     3.0
# 1060            40          4                 10                     3.0
# 1061            40          4                 10                     3.0
#
# [768 rows x 15 columns]

# %%
temp2[temp2['user_id'] == 27]
# Out:
#           order_id  product_id  add_to_cart_order  reordered  \
# 66686         7099        6799                  1          0
# 66687         7099        8580                  2          0
# 66688         7099       31231                  3          0
# 66689         7099        1185                  4          0
# 66690         7099       44051                  5          0
# ...            ...         ...                ...        ...
# 31994435   3374715       42828                 10          0
# 31994436   3374715        4781                 11          1
# 31994437   3374715       38777                 12          0
# 31994438   3374715       24236                 13          0
# 31994439   3374715       42356                 14          0
#
#                                                product_name  aisle_id  \
# 66686                             Revive Zero Vitamin Water        64
# 66687     VitaminWater Zero™ XXX Acai Blueberry Pomegranate        64
# 66688                        Vitamin Water Zero Rise Orange        64
# 66689            Energy Tropical Citrus Vitamin Water Drink        64
# 66690                                    Zero Vitamin Water        64
# ...                                                     ...       ...
# 31994435                               Whipped Cream Cheese       108
# 31994436                      Original Coconut Milk Creamer        91
# 31994437                      Organic Green Seedless Grapes       123
# 31994438  Organic  Dried & Unsulfured Orchard Select Apr...       117
# 31994439                               Strawberry Preserves        88
#
#           department_id                       aisle  department  user_id  \
# 66686                 7        energy sports drinks   beverages       27
# 66687                 7        energy sports drinks   beverages       27
# 66688                 7        energy sports drinks   beverages       27
# 66689                 7        energy sports drinks   beverages       27
# 66690                 7        energy sports drinks   beverages       27
# ...                 ...                         ...         ...      ...
# 31994435             16        other creams cheeses  dairy eggs       27
# 31994436             16             soy lactosefree  dairy eggs       27
# 31994437              4  packaged vegetables fruits     produce       27
# 31994438             19      nuts seeds dried fruit      snacks       27
# 31994439             13                     spreads      pantry       27
#
#          eval_set  order_number  order_dow  order_hour_of_day  \
# 66686       prior            63          3                 10
# 66687       prior            63          3                 10
# 66688       prior            63          3                 10
# 66689       prior            63          3                 10
# 66690       prior            63          3                 10
# ...           ...           ...        ...                ...
# 31994435    prior            40          4                 10
# 31994436    prior            40          4                 10
# 31994437    prior            40          4                 10
# 31994438    prior            40          4                 10
# 31994439    prior            40          4                 10
#
#           days_since_prior_order
# 66686                        1.0
# 66687                        1.0
# 66688                        1.0
# 66689                        1.0
# 66690                        1.0
# ...                          ...
# 31994435                     3.0
# 31994436                     3.0
# 31994437                     3.0
# 31994438                     3.0
# 31994439                     3.0
#
# [768 rows x 15 columns]

# %%
vip_df['aisle'].unique()
# Out:
# array(['water seltzer sparkling water', 'eggs', 'white wines',
#        'instant foods', 'hot cereal pancake mixes', 'condiments',
#        'coffee', 'packaged cheese', 'soft drinks', 'ice cream ice',
#        'frozen meals', 'fresh fruits', 'bread', 'dish detergents',
#        'lunch meat', 'spreads', 'marinades meat preparation',
#        'other creams cheeses', 'paper goods', 'cereal', 'popcorn jerky',
#        'spirits', 'granola', 'yogurt', 'soup broth bouillon',
#        'baking ingredients', 'laundry', 'nuts seeds dried fruit',
#        'butter', 'frozen breakfast', 'pickled goods olives',
#        'frozen produce', 'food storage', 'spices seasonings',
#        'energy sports drinks', 'soy lactosefree', 'chips pretzels',
#        'juice nectars', 'energy granola bars', 'breakfast bars pastries',
#        'packaged vegetables fruits', 'breakfast bakery',
#        'honeys syrups nectars', 'refrigerated', 'tea', 'soap',
#        'cleaning products', 'cream', 'milk', 'packaged produce',
#        'mint gum', 'fresh vegetables', 'fresh herbs', 'cookies cakes',
#        'specialty cheeses', 'asian foods', 'fruit vegetable snacks',
#        'cold flu allergy', 'crackers', 'oils vinegars',
#        'baby food formula', 'vitamins supplements', 'buns rolls',
#        'diapers wipes', 'tortillas flat bread', 'dry pasta', 'skin care',
#        'poultry counter', 'ice cream toppings', 'grains rice dried goods',
#        'canned jarred vegetables', 'salad dressing toppings',
#        'canned meals beans', 'cocoa drink mixes', 'pasta sauce',
#        'candy chocolate', 'meat counter', 'packaged meat',
#        'frozen meat seafood', 'seafood counter', 'prepared meals',
#        'latino foods', 'fresh dips tapenades', 'air fresheners candles',
#        'hot dogs bacon sausage', 'packaged poultry',
#        'tofu meat alternatives', 'body lotions soap',
#        'muscles joints pain relief', 'preserved dips spreads',
#        'bulk dried fruits vegetables', 'missing', 'prepared soups salads',
#        'canned fruit applesauce', 'doughs gelatins bake mixes',
#        'packaged seafood', 'frozen pizza', 'protein meal replacements',
#        'baking supplies decor', 'oral hygiene', 'frozen dessert',
#        'frozen vegan vegetarian', 'refrigerated pudding desserts',
#        'frozen appetizers sides', 'bakery desserts', 'indian foods',
#        'trail mix snack mix', 'frozen breads doughs', 'fresh pasta',
#        'canned meat seafood', 'other', 'plates bowls cups flatware',
#        'feminine care', 'more household', 'cat food care',
#        'trash bags liners', 'hair care', 'kitchen supplies',
#        'dog food care', 'beauty', 'kosher foods', 'first aid',
#        'deodorants', 'eye ear care', 'beers coolers',
#        'specialty wines champagnes', 'red wines', 'baby accessories',
#        'baby bath body care', 'bulk grains rice dried goods', 'digestion',
#        'shave needs', 'facial care', 'frozen juice'], dtype=object)

# %%
vip_df['department'].unique()
# Out:
# array(['beverages', 'dairy eggs', 'alcohol', 'dry goods pasta',
#        'breakfast', 'pantry', 'frozen', 'produce', 'bakery', 'household',
#        'deli', 'snacks', 'canned goods', 'personal care', 'international',
#        'babies', 'meat seafood', 'bulk', 'missing', 'other', 'pets'],
#       dtype=object)

# %%
vip_department = vip_df.groupby(['department']).count().sort_values(by='user_id', ascending=False)
vip_department
# Out:
#                  user_id  order_id  product_id  add_to_cart_order  reordered  \
# department
# produce          3258909   3258909     3258909            3258909    3258909
# dairy eggs       1897713   1897713     1897713            1897713    1897713
# snacks            976348    976348      976348             976348     976348
# beverages         883529    883529      883529             883529     883529
# frozen            634065    634065      634065             634065     634065
# pantry            581605    581605      581605             581605     581605
# bakery            395133    395133      395133             395133     395133
# deli              335745    335745      335745             335745     335745
# canned goods      306328    306328      306328             306328     306328
# dry goods pasta   252389    252389      252389             252389     252389
# breakfast         231590    231590      231590             231590     231590
# meat seafood      210942    210942      210942             210942     210942
# household         204126    204126      204126             204126     204126
# babies            172578    172578      172578             172578     172578
# personal care     127963    127963      127963             127963     127963
# international      81284     81284       81284              81284      81284
# alcohol            40355     40355       40355              40355      40355
# pets               26615     26615       26615              26615      26615
# missing            18976     18976       18976              18976      18976
# bulk               14357     14357       14357              14357      14357
# other              11051     11051       11051              11051      11051
#
#                  product_name  aisle_id  department_id    aisle  eval_set  \
# department
# produce               3258909   3258909        3258909  3258909   3258909
# dairy eggs            1897713   1897713        1897713  1897713   1897713
# snacks                 976348    976348         976348   976348    976348
# beverages              883529    883529         883529   883529    883529
# frozen                 634065    634065         634065   634065    634065
# pantry                 581605    581605         581605   581605    581605
# bakery                 395133    395133         395133   395133    395133
# deli                   335745    335745         335745   335745    335745
# canned goods           306328    306328         306328   306328    306328
# dry goods pasta        252389    252389         252389   252389    252389
# breakfast              231590    231590         231590   231590    231590
# meat seafood           210942    210942         210942   210942    210942
# household              204126    204126         204126   204126    204126
# babies                 172578    172578         172578   172578    172578
# personal care          127963    127963         127963   127963    127963
# international           81284     81284          81284    81284     81284
# alcohol                 40355     40355          40355    40355     40355
# pets                    26615     26615          26615    26615     26615
# missing                 18976     18976          18976    18976     18976
# bulk                    14357     14357          14357    14357     14357
# other                   11051     11051          11051    11051     11051
#
#                  order_number  order_dow  order_hour_of_day  \
# department
# produce               3258909    3258909            3258909
# dairy eggs            1897713    1897713            1897713
# snacks                 976348     976348             976348
# beverages              883529     883529             883529
# frozen                 634065     634065             634065
# pantry                 581605     581605             581605
# bakery                 395133     395133             395133
# deli                   335745     335745             335745
# canned goods           306328     306328             306328
# dry goods pasta        252389     252389             252389
# breakfast              231590     231590             231590
# meat seafood           210942     210942             210942
# household              204126     204126             204126
# babies                 172578     172578             172578
# personal care          127963     127963             127963
# international           81284      81284              81284
# alcohol                 40355      40355              40355
# pets                    26615      26615              26615
# missing                 18976      18976              18976
# bulk                    14357      14357              14357
# other                   11051      11051              11051
#
#                  days_since_prior_order
# department
# produce                         3198034
# dairy eggs                      1862588
# snacks                           957888
# beverages                        867949
# frozen                           621541
# pantry                           570819
# bakery                           387826
# deli                             329169
# canned goods                     300739
# dry goods pasta                  247383
# breakfast                        227079
# meat seafood                     206966
# household                        200461
# babies                           169460
# personal care                    125830
# international                     79598
# alcohol                           39669
# pets                              26139
# missing                           18960
# bulk                              14109
# other                             10863

# %%
vip_df.groupby(['department', 'reordered']).count().sort_values(by=['user_id'], ascending=False)
# Out:
#                            user_id  order_id  product_id  add_to_cart_order  \
# department      reordered
# produce         1          2579529   2579529     2579529            2579529
# dairy eggs      1          1540889   1540889     1540889            1540889
# beverages       1           693983    693983      693983             693983
# snacks          1           693573    693573      693573             693573
# produce         0           679380    679380      679380             679380
# frozen          1           436274    436274      436274             436274
# dairy eggs      0           356824    356824      356824             356824
# bakery          1           306175    306175      306175             306175
# pantry          0           294722    294722      294722             294722
#                 1           286883    286883      286883             286883
# snacks          0           282775    282775      282775             282775
# deli            1           252628    252628      252628             252628
# frozen          0           197791    197791      197791             197791
# beverages       0           189546    189546      189546             189546
# canned goods    1           188572    188572      188572             188572
# breakfast       1           164984    164984      164984             164984
# dry goods pasta 1           155199    155199      155199             155199
# meat seafood    1           152061    152061      152061             152061
# babies          1           121325    121325      121325             121325
# canned goods    0           117756    117756      117756             117756
# household       1           116606    116606      116606             116606
# dry goods pasta 0            97190     97190       97190              97190
# bakery          0            88958     88958       88958              88958
# household       0            87520     87520       87520              87520
# deli            0            83117     83117       83117              83117
# personal care   0            69699     69699       69699              69699
# breakfast       0            66606     66606       66606              66606
# meat seafood    0            58881     58881       58881              58881
# personal care   1            58264     58264       58264              58264
# babies          0            51253     51253       51253              51253
# international   1            41444     41444       41444              41444
#                 0            39840     39840       39840              39840
# alcohol         1            29967     29967       29967              29967
# pets            1            20130     20130       20130              20130
# alcohol         0            10388     10388       10388              10388
# bulk            1            10135     10135       10135              10135
# missing         1             9526      9526        9526               9526
#                 0             9450      9450        9450               9450
# pets            0             6485      6485        6485               6485
# other           1             6102      6102        6102               6102
#                 0             4949      4949        4949               4949
# bulk            0             4222      4222        4222               4222
#
#                            product_name  aisle_id  department_id    aisle  \
# department      reordered
# produce         1               2579529   2579529        2579529  2579529
# dairy eggs      1               1540889   1540889        1540889  1540889
# beverages       1                693983    693983         693983   693983
# snacks          1                693573    693573         693573   693573
# produce         0                679380    679380         679380   679380
# frozen          1                436274    436274         436274   436274
# dairy eggs      0                356824    356824         356824   356824
# bakery          1                306175    306175         306175   306175
# pantry          0                294722    294722         294722   294722
#                 1                286883    286883         286883   286883
# snacks          0                282775    282775         282775   282775
# deli            1                252628    252628         252628   252628
# frozen          0                197791    197791         197791   197791
# beverages       0                189546    189546         189546   189546
# canned goods    1                188572    188572         188572   188572
# breakfast       1                164984    164984         164984   164984
# dry goods pasta 1                155199    155199         155199   155199
# meat seafood    1                152061    152061         152061   152061
# babies          1                121325    121325         121325   121325
# canned goods    0                117756    117756         117756   117756
# household       1                116606    116606         116606   116606
# dry goods pasta 0                 97190     97190          97190    97190
# bakery          0                 88958     88958          88958    88958
# household       0                 87520     87520          87520    87520
# deli            0                 83117     83117          83117    83117
# personal care   0                 69699     69699          69699    69699
# breakfast       0                 66606     66606          66606    66606
# meat seafood    0                 58881     58881          58881    58881
# personal care   1                 58264     58264          58264    58264
# babies          0                 51253     51253          51253    51253
# international   1                 41444     41444          41444    41444
#                 0                 39840     39840          39840    39840
# alcohol         1                 29967     29967          29967    29967
# pets            1                 20130     20130          20130    20130
# alcohol         0                 10388     10388          10388    10388
# bulk            1                 10135     10135          10135    10135
# missing         1                  9526      9526           9526     9526
#                 0                  9450      9450           9450     9450
# pets            0                  6485      6485           6485     6485
# other           1                  6102      6102           6102     6102
#                 0                  4949      4949           4949     4949
# bulk            0                  4222      4222           4222     4222
#
#                            eval_set  order_number  order_dow  \
# department      reordered
# produce         1           2579529       2579529    2579529
# dairy eggs      1           1540889       1540889    1540889
# beverages       1            693983        693983     693983
# snacks          1            693573        693573     693573
# produce         0            679380        679380     679380
# frozen          1            436274        436274     436274
# dairy eggs      0            356824        356824     356824
# bakery          1            306175        306175     306175
# pantry          0            294722        294722     294722
#                 1            286883        286883     286883
# snacks          0            282775        282775     282775
# deli            1            252628        252628     252628
# frozen          0            197791        197791     197791
# beverages       0            189546        189546     189546
# canned goods    1            188572        188572     188572
# breakfast       1            164984        164984     164984
# dry goods pasta 1            155199        155199     155199
# meat seafood    1            152061        152061     152061
# babies          1            121325        121325     121325
# canned goods    0            117756        117756     117756
# household       1            116606        116606     116606
# dry goods pasta 0             97190         97190      97190
# bakery          0             88958         88958      88958
# household       0             87520         87520      87520
# deli            0             83117         83117      83117
# personal care   0             69699         69699      69699
# breakfast       0             66606         66606      66606
# meat seafood    0             58881         58881      58881
# personal care   1             58264         58264      58264
# babies          0             51253         51253      51253
# international   1             41444         41444      41444
#                 0             39840         39840      39840
# alcohol         1             29967         29967      29967
# pets            1             20130         20130      20130
# alcohol         0             10388         10388      10388
# bulk            1             10135         10135      10135
# missing         1              9526          9526       9526
#                 0              9450          9450       9450
# pets            0              6485          6485       6485
# other           1              6102          6102       6102
#                 0              4949          4949       4949
# bulk            0              4222          4222       4222
#
#                            order_hour_of_day  days_since_prior_order
# department      reordered
# produce         1                    2579529                 2579529
# dairy eggs      1                    1540889                 1540889
# beverages       1                     693983                  693983
# snacks          1                     693573                  693573
# produce         0                     679380                  618505
# frozen          1                     436274                  436274
# dairy eggs      0                     356824                  321699
# bakery          1                     306175                  306175
# pantry          0                     294722                  283936
#                 1                     286883                  286883
# snacks          0                     282775                  264315
# deli            1                     252628                  252628
# frozen          0                     197791                  185267
# beverages       0                     189546                  173966
# canned goods    1                     188572                  188572
# breakfast       1                     164984                  164984
# dry goods pasta 1                     155199                  155199
# meat seafood    1                     152061                  152061
# babies          1                     121325                  121325
# canned goods    0                     117756                  112167
# household       1                     116606                  116606
# dry goods pasta 0                      97190                   92184
# bakery          0                      88958                   81651
# household       0                      87520                   83855
# deli            0                      83117                   76541
# personal care   0                      69699                   67566
# breakfast       0                      66606                   62095
# meat seafood    0                      58881                   54905
# personal care   1                      58264                   58264
# babies          0                      51253                   48135
# international   1                      41444                   41444
#                 0                      39840                   38154
# alcohol         1                      29967                   29967
# pets            1                      20130                   20130
# alcohol         0                      10388                    9702
# bulk            1                      10135                   10135
# missing         1                       9526                    9526
#                 0                       9450                    9434
# pets            0                       6485                    6009
# other           1                       6102                    6102
#                 0                       4949                    4761
# bulk            0                       4222                    3974

# %%
vip_department['user_id']
# Out:
# department
# produce            3258909
# dairy eggs         1897713
# snacks              976348
# beverages           883529
# frozen              634065
# pantry              581605
# bakery              395133
# deli                335745
# canned goods        306328
# dry goods pasta     252389
# breakfast           231590
# meat seafood        210942
# household           204126
# babies              172578
# personal care       127963
# international        81284
# alcohol              40355
# pets                 26615
# missing              18976
# bulk                 14357
# other                11051
# Name: user_id, dtype: int64

# %%
plt.figure(figsize=(25, 10))
ax1 = sns.barplot(data=vip_department, x='user_id', y=vip_department.index)
# containers1 = ax1.containers[0]
# ax1.bar_label(containers1, labels=[f'{x:,.0f}' for x in containers1.datavalues], label_type='edge')
plt.title('Departments of VIP customers', fontsize=18)
plt.show()

# %%
vip_df[vip_df['department']=='produce']
# Out:
#           user_id  order_id  product_id  add_to_cart_order  reordered  \
# 15             17    348137       16797                 10          1
# 34             17    603376       16797                  5          1
# 64             17    697863        9387                  5          1
# 84             17    805025       16797                  8          1
# 85             17    805025        9387                  9          0
# ...           ...       ...         ...                ...        ...
# 10661583   206208   3392839       13984                  7          0
# 10661584   206208   3392839       20114                  8          0
# 10661585   206208   3392839       48364                  9          0
# 10661586   206208   3392839       43122                 10          0
# 10661590   206208   3412250       27966                  2          1
#
#                    product_name  aisle_id  department_id  \
# 15                 Strawberries        24              4
# 34                 Strawberries        24              4
# 64          Granny Smith Apples        24              4
# 84                 Strawberries        24              4
# 85          Granny Smith Apples        24              4
# ...                         ...       ...            ...
# 10661583           Organic Mint        16              4
# 10661584       Jalapeno Peppers        83              4
# 10661585            Sweet Onion        83              4
# 10661586  Organic Bartlett Pear        24              4
# 10661590    Organic Raspberries       123              4
#
#                                aisle department eval_set  order_number  \
# 15                      fresh fruits    produce    prior            39
# 34                      fresh fruits    produce    prior            22
# 64                      fresh fruits    produce    prior            29
# 84                      fresh fruits    produce    prior            11
# 85                      fresh fruits    produce    prior            11
# ...                              ...        ...      ...           ...
# 10661583                 fresh herbs    produce    prior             3
# 10661584            fresh vegetables    produce    prior             3
# 10661585            fresh vegetables    produce    prior             3
# 10661586                fresh fruits    produce    prior             3
# 10661590  packaged vegetables fruits    produce    prior            29
#
#           order_dow  order_hour_of_day  days_since_prior_order
# 15                5                 16                    11.0
# 34                6                 16                     4.0
# 64                6                 14                     5.0
# 84                4                 15                     4.0
# 85                4                 15                     4.0
# ...             ...                ...                     ...
# 10661583          2                 15                     7.0
# 10661584          2                 15                     7.0
# 10661585          2                 15                     7.0
# 10661586          2                 15                     7.0
# 10661590          4                 18                     4.0
#
# [3258909 rows x 15 columns]

# %%
len(vip_df)
# Out:
# 10661601

# %%
vip_department.describe()
# Out:
#             user_id      order_id    product_id  add_to_cart_order  \
# count  2.100000e+01  2.100000e+01  2.100000e+01       2.100000e+01
# mean   5.076953e+05  5.076953e+05  5.076953e+05       5.076953e+05
# std    7.715283e+05  7.715283e+05  7.715283e+05       7.715283e+05
# min    1.105100e+04  1.105100e+04  1.105100e+04       1.105100e+04
# 25%    8.128400e+04  8.128400e+04  8.128400e+04       8.128400e+04
# 50%    2.315900e+05  2.315900e+05  2.315900e+05       2.315900e+05
# 75%    5.816050e+05  5.816050e+05  5.816050e+05       5.816050e+05
# max    3.258909e+06  3.258909e+06  3.258909e+06       3.258909e+06
#
#           reordered  product_name      aisle_id  department_id         aisle  \
# count  2.100000e+01  2.100000e+01  2.100000e+01   2.100000e+01  2.100000e+01
# mean   5.076953e+05  5.076953e+05  5.076953e+05   5.076953e+05  5.076953e+05
# std    7.715283e+05  7.715283e+05  7.715283e+05   7.715283e+05  7.715283e+05
# min    1.105100e+04  1.105100e+04  1.105100e+04   1.105100e+04  1.105100e+04
# 25%    8.128400e+04  8.128400e+04  8.128400e+04   8.128400e+04  8.128400e+04
# 50%    2.315900e+05  2.315900e+05  2.315900e+05   2.315900e+05  2.315900e+05
# 75%    5.816050e+05  5.816050e+05  5.816050e+05   5.816050e+05  5.816050e+05
# max    3.258909e+06  3.258909e+06  3.258909e+06   3.258909e+06  3.258909e+06
#
#            eval_set  order_number     order_dow  order_hour_of_day  \
# count  2.100000e+01  2.100000e+01  2.100000e+01       2.100000e+01
# mean   5.076953e+05  5.076953e+05  5.076953e+05       5.076953e+05
# std    7.715283e+05  7.715283e+05  7.715283e+05       7.715283e+05
# min    1.105100e+04  1.105100e+04  1.105100e+04       1.105100e+04
# 25%    8.128400e+04  8.128400e+04  8.128400e+04       8.128400e+04
# 50%    2.315900e+05  2.315900e+05  2.315900e+05       2.315900e+05
# 75%    5.816050e+05  5.816050e+05  5.816050e+05       5.816050e+05
# max    3.258909e+06  3.258909e+06  3.258909e+06       3.258909e+06
#
#        days_since_prior_order
# count            2.100000e+01
# mean             4.982414e+05
# std              7.571446e+05
# min              1.086300e+04
# 25%              7.959800e+04
# 50%              2.270790e+05
# 75%              5.708190e+05
# max              3.198034e+06

# %%
vip_aisle = vip_df.groupby(['aisle']).count().sort_values(by='user_id', ascending=False)
vip_aisle
# Out:
#                             user_id  order_id  product_id  add_to_cart_order  \
# aisle
# fresh fruits                1330846   1330846     1330846            1330846
# fresh vegetables            1122382   1122382     1122382            1122382
# packaged vegetables fruits   596012    596012      596012             596012
# yogurt                       526731    526731      526731             526731
# milk                         346909    346909      346909             346909
# ...                             ...       ...         ...                ...
# shave needs                    2197      2197        2197               2197
# facial care                    2069      2069        2069               2069
# beauty                         1693      1693        1693               1693
# eye ear care                   1606      1606        1606               1606
# frozen juice                   1155      1155        1155               1155
#
#                             reordered  product_name  aisle_id  department_id  \
# aisle
# fresh fruits                  1330846       1330846   1330846        1330846
# fresh vegetables              1122382       1122382   1122382        1122382
# packaged vegetables fruits     596012        596012    596012         596012
# yogurt                         526731        526731    526731         526731
# milk                           346909        346909    346909         346909
# ...                               ...           ...       ...            ...
# shave needs                      2197          2197      2197           2197
# facial care                      2069          2069      2069           2069
# beauty                           1693          1693      1693           1693
# eye ear care                     1606          1606      1606           1606
# frozen juice                     1155          1155      1155           1155
#
#                             department  eval_set  order_number  order_dow  \
# aisle
# fresh fruits                   1330846   1330846       1330846    1330846
# fresh vegetables               1122382   1122382       1122382    1122382
# packaged vegetables fruits      596012    596012        596012     596012
# yogurt                          526731    526731        526731     526731
# milk                            346909    346909        346909     346909
# ...                                ...       ...           ...        ...
# shave needs                       2197      2197          2197       2197
# facial care                       2069      2069          2069       2069
# beauty                            1693      1693          1693       1693
# eye ear care                      1606      1606          1606       1606
# frozen juice                      1155      1155          1155       1155
#
#                             order_hour_of_day  days_since_prior_order
# aisle
# fresh fruits                          1330846                 1306082
# fresh vegetables                      1122382                 1101570
# packaged vegetables fruits             596012                  584712
# yogurt                                 526731                  516438
# milk                                   346909                  340608
# ...                                       ...                     ...
# shave needs                              2197                    2168
# facial care                              2069                    2023
# beauty                                   1693                    1648
# eye ear care                             1606                    1564
# frozen juice                             1155                    1135
#
# [134 rows x 14 columns]

# %%
vip_aisle['user_id']
# Out:
# aisle
# fresh fruits                  1330846
# fresh vegetables              1122382
# packaged vegetables fruits     596012
# yogurt                         526731
# milk                           346909
#                                ...
# shave needs                      2197
# facial care                      2069
# beauty                           1693
# eye ear care                     1606
# frozen juice                     1155
# Name: user_id, Length: 134, dtype: int64

# %%
vip_aisle_top_10 = vip_aisle['user_id'].head(10)
vip_aisle_top_10 = vip_aisle_top_10.reset_index()

# %%
plt.figure(figsize=(25, 10))
ax2 = sns.barplot(data=vip_aisle_top_10, x='aisle', y='user_id')
# containers2 = ax2.containers[-1]
# ax2.bar_label(containers2, labels=[f'{x:,.0f}' for x in containers2.datavalues], label_type='center')
plt.title('Top 10 aisles of VIP customers', fontsize=18)
plt.show()

# %%
plt.figure(figsize=(25, 10))
sns.histplot(data=temp3, x='department')

# %%
order_number_normal2 = order_number_normal.reset_index()
order_number_normal2 = order_number_normal2['user_id']
order_number_normal2
# Out:
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5
#            ...
# 188302    206203
# 188303    206204
# 188304    206205
# 188305    206207
# 188306    206209
# Name: user_id, Length: 188307, dtype: int64

# %%
print(len(order_number_vip2))
print(len(order_number_normal2))
# Out:
# 17902
# 188307

# %%
normal_df = pd.merge(left=order_number_normal2, right=temp2, how='left')
normal_df
# Out:
#           user_id  order_id  product_id  add_to_cart_order  reordered  \
# 0               1    431534         196                  1          1
# 1               1    431534       12427                  2          1
# 2               1    431534       10258                  3          1
# 3               1    431534       25133                  4          1
# 4               1    431534       10326                  5          0
# ...           ...       ...         ...                ...        ...
# 21772883   206209   3154581       20842                 11          0
# 21772884   206209   3154581       23594                 12          0
# 21772885   206209   3154581       25837                 13          0
# 21772886   206209   3186442       14197                  1          0
# 21772887   206209   3186442        6187                  2          1
#
#                                       product_name  aisle_id  department_id  \
# 0                                             Soda        77              7
# 1                              Original Beef Jerky        23             19
# 2                                       Pistachios       117             19
# 3                            Organic String Cheese        21             16
# 4                              Organic Fuji Apples        24              4
# ...                                            ...       ...            ...
# 21772883                     Total 0% Greek Yogurt       120             16
# 21772884                              Medium Salsa        51             13
# 21772885  Mini Babybel Light Semisoft Edam Cheeses        21             16
# 21772886                              Tomato Paste         9              9
# 21772887                        Raisin Bran Cereal       121             14
#
#                            aisle       department eval_set  order_number  \
# 0                    soft drinks        beverages    prior             5
# 1                  popcorn jerky           snacks    prior             5
# 2         nuts seeds dried fruit           snacks    prior             5
# 3                packaged cheese       dairy eggs    prior             5
# 4                   fresh fruits          produce    prior             5
# ...                          ...              ...      ...           ...
# 21772883                  yogurt       dairy eggs    prior             1
# 21772884  preserved dips spreads           pantry    prior             1
# 21772885         packaged cheese       dairy eggs    prior             1
# 21772886             pasta sauce  dry goods pasta    prior             6
# 21772887                  cereal        breakfast    prior             6
#
#           order_dow  order_hour_of_day  days_since_prior_order
# 0                 4                 15                    28.0
# 1                 4                 15                    28.0
# 2                 4                 15                    28.0
# 3                 4                 15                    28.0
# 4                 4                 15                    28.0
# ...             ...                ...                     ...
# 21772883          3                 11                     NaN
# 21772884          3                 11                     NaN
# 21772885          3                 11                     NaN
# 21772886          0                 16                     3.0
# 21772887          0                 16                     3.0
#
# [21772888 rows x 15 columns]

# %%
normal_department = normal_df.groupby('user_id')

# %%
plt.figure(figsize=(15,15))
sns.histplot(data=normal_df, y='department', hue='department')

# %%
plt.figure(figsize=(15,15))
sns.histplot(data=normal_df, y='department', hue='department')

# %%
# temp_data = SalesLog['Payment'].groupby(SalesLog['Month']).sum()
# ax = plt.bar(temp_data.index, temp_data)
# plt.bar_label(ax, labels=[f'{x:,.0f}' for x in ax.datavalues], label_type='center')
# plt.title('Payments by Month')
# plt.show()

# %%
normal_df['reordered'].value_counts()
# Out:
# 1    11262287
# 0    10510601
# Name: reordered, dtype: int64

# %%
normal_df.groupby('department').count()['reordered'].sort_values(ascending=False)
# Out:
# department
# produce            6220382
# dairy eggs         3516303
# snacks             1911202
# beverages          1806600
# frozen             1602367
# pantry             1293972
# bakery              781654
# canned goods        761730
# deli                715504
# dry goods pasta     614238
# household           534540
# meat seafood        497989
# breakfast           477979
# personal care       319160
# babies              251224
# international       187969
# alcohol             113341
# pets                 71109
# missing              50169
# other                25240
# bulk                 20216
# Name: reordered, dtype: int64

# %% [markdown]
# # add to cart 순위 / order number 순위와 비교해보자!

# %%
temp2['add_to_cart_order'].max()    # 최대 145번째까지 있음
# 전체 고객데이터: 카트에 담긴 순서가, 많은 순서대로(대분류, 소분류)
# 카트에 담긴 순서 상위 1번째 ~ 10번째까지 담긴 상품들이 무엇인지 확인
cart_rank = temp2.sort_values(by = ['add_to_cart_order', 'department', 'aisle'])
cart_rank
# Out:
#           order_id  product_id  add_to_cart_order  reordered  \
# 112             13       17330                  1          0
# 4256           446       28442                  1          0
# 7424           770       45432                  1          1
# 14322         1500       30736                  1          1
# 18788         1986       46088                  1          0
# ...            ...         ...                ...        ...
# 14825326   1564244       46346                141          0
# 14825327   1564244       22594                142          0
# 14825328   1564244       21230                143          0
# 14825329   1564244       43182                144          0
# 14825330   1564244       23737                145          0
#
#                                  product_name  aisle_id  department_id  \
# 112                                     Light        27              5
# 4256                      Coronita Beer Extra        27              5
# 7424            Brewmaster's Seasonal Sampler        27              5
# 14322                  Hard Cider Crisp Apple        27              5
# 18788                                    Beer        27              5
# ...                                       ...       ...            ...
# 14825326     Sweet Potato Fries with Sea Salt       129              1
# 14825327  Quattro Formaggi Four Cheeses Pizza        13             20
# 14825328       Organic Himalayan Pink Popcorn        23             19
# 14825329                        Almond Butter         3             19
# 14825330       Organic 100% Grapefruit  Juice        31              7
#
#                             aisle department  user_id eval_set  order_number  \
# 112                 beers coolers    alcohol    45082    prior             2
# 4256                beers coolers    alcohol    22274    prior            93
# 7424                beers coolers    alcohol   165709    prior            11
# 14322               beers coolers    alcohol   162652    prior             8
# 18788               beers coolers    alcohol    79780    prior            11
# ...                           ...        ...      ...      ...           ...
# 14825326  frozen appetizers sides     frozen    22906    prior             4
# 14825327           prepared meals       deli    22906    prior             4
# 14825328            popcorn jerky     snacks    22906    prior             4
# 14825329      energy granola bars     snacks    22906    prior             4
# 14825330             refrigerated  beverages    22906    prior             4
#
#           order_dow  order_hour_of_day  days_since_prior_order
# 112               6                 17                     1.0
# 4256              5                 13                     0.0
# 7424              4                  0                     2.0
# 14322             4                 12                     7.0
# 18788             1                 18                     4.0
# ...             ...                ...                     ...
# 14825326          2                 10                    30.0
# 14825327          2                 10                    30.0
# 14825328          2                 10                    30.0
# 14825329          2                 10                    30.0
# 14825330          2                 10                    30.0
#
# [32434489 rows x 15 columns]

# %%
cart_rank1 = cart_rank[cart_rank['add_to_cart_order']==1]
cart_rank1_dep = cart_rank1.groupby('department').count()
cart_rank1_dep.sort_values(by='order_id', ascending=False)
# Out:
#                  order_id  product_id  add_to_cart_order  reordered  \
# department
# produce            901240      901240             901240     901240
# dairy eggs         650837      650837             650837     650837
# beverages          409796      409796             409796     409796
# snacks             225282      225282             225282     225282
# frozen             182103      182103             182103     182103
# pantry             154850      154850             154850     154850
# bakery             117705      117705             117705     117705
# deli                88297       88297              88297      88297
# household           84805       84805              84805      84805
# meat seafood        71282       71282              71282      71282
# canned goods        63028       63028              63028      63028
# breakfast           56713       56713              56713      56713
# personal care       51684       51684              51684      51684
# dry goods pasta     51584       51584              51584      51584
# alcohol             34850       34850              34850      34850
# babies              24831       24831              24831      24831
# international       19772       19772              19772      19772
# pets                12294       12294              12294      12294
# missing              5412        5412               5412       5412
# other                4867        4867               4867       4867
# bulk                 3642        3642               3642       3642
#
#                  product_name  aisle_id  department_id   aisle  user_id  \
# department
# produce                901240    901240         901240  901240   901240
# dairy eggs             650837    650837         650837  650837   650837
# beverages              409796    409796         409796  409796   409796
# snacks                 225282    225282         225282  225282   225282
# frozen                 182103    182103         182103  182103   182103
# pantry                 154850    154850         154850  154850   154850
# bakery                 117705    117705         117705  117705   117705
# deli                    88297     88297          88297   88297    88297
# household               84805     84805          84805   84805    84805
# meat seafood            71282     71282          71282   71282    71282
# canned goods            63028     63028          63028   63028    63028
# breakfast               56713     56713          56713   56713    56713
# personal care           51684     51684          51684   51684    51684
# dry goods pasta         51584     51584          51584   51584    51584
# alcohol                 34850     34850          34850   34850    34850
# babies                  24831     24831          24831   24831    24831
# international           19772     19772          19772   19772    19772
# pets                    12294     12294          12294   12294    12294
# missing                  5412      5412           5412    5412     5412
# other                    4867      4867           4867    4867     4867
# bulk                     3642      3642           3642    3642     3642
#
#                  eval_set  order_number  order_dow  order_hour_of_day  \
# department
# produce            901240        901240     901240             901240
# dairy eggs         650837        650837     650837             650837
# beverages          409796        409796     409796             409796
# snacks             225282        225282     225282             225282
# frozen             182103        182103     182103             182103
# pantry             154850        154850     154850             154850
# bakery             117705        117705     117705             117705
# deli                88297         88297      88297              88297
# household           84805         84805      84805              84805
# meat seafood        71282         71282      71282              71282
# canned goods        63028         63028      63028              63028
# breakfast           56713         56713      56713              56713
# personal care       51684         51684      51684              51684
# dry goods pasta     51584         51584      51584              51584
# alcohol             34850         34850      34850              34850
# babies              24831         24831      24831              24831
# international       19772         19772      19772              19772
# pets                12294         12294      12294              12294
# missing              5412          5412       5412               5412
# other                4867          4867       4867               4867
# bulk                 3642          3642       3642               3642
#
#                  days_since_prior_order
# department
# produce                          845708
# dairy eggs                       610783
# beverages                        382831
# snacks                           210625
# frozen                           168972
# pantry                           145610
# bakery                           109959
# deli                              82431
# household                         78892
# meat seafood                      66375
# canned goods                      58986
# breakfast                         52847
# personal care                     48176
# dry goods pasta                   48145
# alcohol                           31914
# babies                            23412
# international                     18435
# pets                              11371
# missing                            5220
# other                              4529
# bulk                               3444

# %%
cart_rank1_ai = cart_rank1.groupby('aisle').count()
cart_rank1_ai.sort_values(by='order_id', ascending=False)
# Out:
#                                order_id  product_id  add_to_cart_order  \
# aisle
# fresh fruits                     445731      445731             445731
# fresh vegetables                 237946      237946             237946
# milk                             189435      189435             189435
# water seltzer sparkling water    160575      160575             160575
# packaged vegetables fruits       142252      142252             142252
# ...                                 ...         ...                ...
# ice cream toppings                  844         844                844
# baby accessories                    804         804                804
# baby bath body care                 794         794                794
# beauty                              708         708                708
# frozen juice                        503         503                503
#
#                                reordered  product_name  aisle_id  \
# aisle
# fresh fruits                      445731        445731    445731
# fresh vegetables                  237946        237946    237946
# milk                              189435        189435    189435
# water seltzer sparkling water     160575        160575    160575
# packaged vegetables fruits        142252        142252    142252
# ...                                  ...           ...       ...
# ice cream toppings                   844           844       844
# baby accessories                     804           804       804
# baby bath body care                  794           794       794
# beauty                               708           708       708
# frozen juice                         503           503       503
#
#                                department_id  department  user_id  eval_set  \
# aisle
# fresh fruits                          445731      445731   445731    445731
# fresh vegetables                      237946      237946   237946    237946
# milk                                  189435      189435   189435    189435
# water seltzer sparkling water         160575      160575   160575    160575
# packaged vegetables fruits            142252      142252   142252    142252
# ...                                      ...         ...      ...       ...
# ice cream toppings                       844         844      844       844
# baby accessories                         804         804      804       804
# baby bath body care                      794         794      794       794
# beauty                                   708         708      708       708
# frozen juice                             503         503      503       503
#
#                                order_number  order_dow  order_hour_of_day  \
# aisle
# fresh fruits                         445731     445731             445731
# fresh vegetables                     237946     237946             237946
# milk                                 189435     189435             189435
# water seltzer sparkling water        160575     160575             160575
# packaged vegetables fruits           142252     142252             142252
# ...                                     ...        ...                ...
# ice cream toppings                      844        844                844
# baby accessories                        804        804                804
# baby bath body care                     794        794                794
# beauty                                  708        708                708
# frozen juice                            503        503                503
#
#                                days_since_prior_order
# aisle
# fresh fruits                                   418611
# fresh vegetables                               223127
# milk                                           178614
# water seltzer sparkling water                  150280
# packaged vegetables fruits                     133565
# ...                                               ...
# ice cream toppings                                797
# baby accessories                                  759
# baby bath body care                               751
# beauty                                            654
# frozen juice                                      475
#
# [134 rows x 14 columns]

# %% [markdown]
# 우리 고객들은 카트에 담으면 그 물건들이 구매로 바로 이어지는 구매 패턴을 보이고 있다. <br>
# (아마 식료품이라서? 사고자 하는 물건들을 바로 구입하는 것으로 보인다) <br>
# 카트상품과 실제 구매 상품이 별 차이가 나지 않기 때문에, 실제 구매가 높은 상품군들을 바탕으로 판매 전략을 짜는 것이 좋아보인다.

# %%
# 전체 고객데이터: 구매 횟수가 많은 순서대로(대분류)
temp2.groupby('department').count()['order_number'].sort_values(ascending=False)
# Out:
# department
# produce            9479291
# dairy eggs         5414016
# snacks             2887550
# beverages          2690129
# frozen             2236432
# pantry             1875577
# bakery             1176787
# canned goods       1068058
# deli               1051249
# dry goods pasta     866627
# household           738666
# breakfast           709569
# meat seafood        708931
# personal care       447123
# babies              423802
# international       269253
# alcohol             153696
# pets                 97724
# missing              69145
# other                36291
# bulk                 34573
# Name: order_number, dtype: int64

# %%
# 전체 고객데이터: 구매 횟수가 많은 순서대로(소분류)
temp2.groupby('aisle').count()['order_number'].sort_values(ascending=False)
# Out:
# aisle
# fresh fruits                  3642188
# fresh vegetables              3418021
# packaged vegetables fruits    1765313
# yogurt                        1452343
# packaged cheese                979763
#                                ...
# eye ear care                     8974
# baby bath body care              8581
# baby accessories                 8160
# beauty                           6168
# frozen juice                     4853
# Name: order_number, Length: 134, dtype: int64
